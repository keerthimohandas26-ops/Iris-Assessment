# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthimohandas26-ops/Iris-Assessment/blob/main/Iris_Assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import zipfile
import os

# Define the path to the zip file and the extraction directory
zip_file_path = '/content/archive.zip'
extraction_dir = '/content/'
csv_file_name = 'IRIS.csv'
csv_file_path = os.path.join(extraction_dir, csv_file_name)

# Check if the CSV file already exists. If not, attempt to unzip the archive.
if not os.path.exists(csv_file_path):
    print(f"'{csv_file_name}' not found. Attempting to unzip '{zip_file_path}'.")
    try:
        with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
            zip_ref.extractall(extraction_dir)
        print(f"Successfully unzipped '{zip_file_path}' to '{extraction_dir}'.")
    except FileNotFoundError:
        print(f"Error: '{zip_file_path}' not found. Please ensure the zip file is in '/content/'.")
    except Exception as e:
        print(f"An unexpected error occurred during unzipping: {e}")
else:
    print(f"'{csv_file_name}' already exists in '{extraction_dir}'. Skipping unzip.")

# Now try to read the CSV file from its expected path
data = pd.read_csv(csv_file_path)

print(data.head())
# Out:
# 'IRIS.csv' not found. Attempting to unzip '/content/archive.zip'.
# Successfully unzipped '/content/archive.zip' to '/content/'.
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
